# %%
import pandas as pd

# %%
df = pd.read_excel('winequality-red.xlsx')

# %%
df
# Out:
#      winequality-red        Unnamed: 1   Unnamed: 2      Unnamed: 3  \
# 0      fixed acidity  volatile acidity  citric acid  residual sugar
# 1                7.4               0.7            0             1.9
# 2                7.8              0.88            0             2.6
# 3                7.8              0.76         0.04             2.3
# 4               11.2              0.28         0.56             1.9
# ...              ...               ...          ...             ...
# 1595             6.2               0.6         0.08               2
# 1596             5.9              0.55          0.1             2.2
# 1597             6.3              0.51         0.13             2.3
# 1598             5.9             0.645         0.12               2
# 1599               6              0.31         0.47             3.6
#
#      Unnamed: 4           Unnamed: 5            Unnamed: 6 Unnamed: 7  \
# 0     chlorides  free sulfur dioxide  total sulfur dioxide    density
# ...
